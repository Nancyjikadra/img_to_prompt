# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancyjikadra/img_to_prompt/blob/main/Copy_of_reverse_stable_diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## reverse stable Diffusion using CLIP MODEL

# %%
pip install clip-interrogator==0.6.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.8/787.8 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 48.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 48.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 111.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 91.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## importing clip interrogator

# %%
from PIL import Image
from clip_interrogator import Interrogator
from clip_interrogator import Config

# %%
image = Image.open("/content/trial.jpg").convert("RGB")

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FAF285E5510>

# %%
from traitlets.traitlets import Integer
ci = Interrogator(Config(clip_model_name="ViT-L-14/openai"))
# Out:
# Loading caption model blip-large...
# ...
# Loading CLIP model ViT-L-14/openai...
# 100%|███████████████████████████████████████| 933M/933M [00:13<00:00, 68.2MiB/s]
# ViT-L-14_openai_artists.safetensors: 100%|██████████| 16.2M/16.2M [00:00<00:00, 26.8MB/s]
# ViT-L-14_openai_flavors.safetensors: 100%|██████████| 155M/155M [00:01<00:00, 140MB/s]
# ViT-L-14_openai_mediums.safetensors: 100%|██████████| 146k/146k [00:00<00:00, 8.55MB/s]
# ViT-L-14_openai_movements.safetensors: 100%|██████████| 307k/307k [00:00<00:00, 11.8MB/s]
# ViT-L-14_openai_trendings.safetensors: 100%|██████████| 111k/111k [00:00<00:00, 9.14MB/s]
# ViT-L-14_openai_negative.safetensors: 100%|██████████| 63.2k/63.2k [00:00<00:00, 7.09MB/s]
# Loaded CLIP model and data in 27.05 seconds.

# %% [markdown]
# ## passing image

# %%
result = ci.interrogate(image)
# Out:
# ...
# 100%|██████████| 50/50 [00:00<00:00, 126.03it/s]

# %%
print(result)
# Out:
# there is a drawing of a robot holding a hammer, cyanotype, by Altichiero, face with artgram, ffffound, robot repair workshop, inspired by George Wyllie, mecha hound, dribbble, droid, autodesk
